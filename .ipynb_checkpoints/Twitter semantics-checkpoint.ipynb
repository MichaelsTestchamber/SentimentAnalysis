# %%
# Sentiment analysis of tweets

# %%
# Import libraries
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# Twitter credentials
APIKey = "rn1i0b2dULhTtAGA7985QAaHl"
APISecret = "Vzl9crKXnnjknc4ejJg45PhkZns8pOeEOpswezvp7SGZOOcUdY"
accesToken = "1247490423846776834-SxSXiR3YhimyvULeozOefJ8cj9o5Ht"
accesTokenSecret = "VmfHc3QhAJtEZA9bZwd8yoB37jGgRmQrJ3pOU1Kn8FujC"

# %%
# Create authentication object
authenticate = tweepy.OAuthHandler(APIKey, APISecret)

# Set acces token and secret
authenticate.set_access_token(accesToken, accesTokenSecret)

# Create API object while passing in the auth info
api = tweepy.API(authenticate, wait_on_rate_limit = True)

# %%
# Extract 100 tweets from twitter user
posts = api.user_timeline(screen_name = "POTUS", count=100, lang = "en", tweet_mode="extended")

# Print last 5 tweets from account
print("Show 5 recent tweets: \n")
for tweet in posts[0:5]:
    print(tweet.full_text + "\n")
# Out:
# Show 5 recent tweets:
#
# RT @WhiteHouse: .@USDA will develop a plan to expedite aid to American farmers and keep our supply chain strong. https://t.co/v3h9uNf3lH
#
# RT @WhiteHouse: In response to the virus, the American people have launched the greatest mobilization of our society since World War II. 🇺🇸…
#
# RT @WhiteHouse: While we encourage Americans to delay elective procedures, we do NOT advise anyone to put off necessary medical treatment.…
#
# RT @WhiteHouse: The data is clear: Our collective national effort is saving many lives. Keep up the fight! https://t.co/MMk1BpwDpg
#
# RT @WhiteHouse: This Sunday, millions of Christians will celebrate Easter.
#
# "At this holy time, we pray that God will heal the sick and co…

# %%
# Create a dataframe with column called called tweets
df = pd.DataFrame( [tweet.full_text for tweet in posts] , columns=['Tweets'])

# Show df head
df.head()
# Out:
#                                               Tweets
# 0  RT @WhiteHouse: .@USDA will develop a plan to ...
# 1  RT @WhiteHouse: In response to the virus, the ...
# 2  RT @WhiteHouse: While we encourage Americans t...
# 3  RT @WhiteHouse: The data is clear: Our collect...
# 4  RT @WhiteHouse: This Sunday, millions of Chris...

# %%
# Clean up the text

#Create function to clean the tweets
def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # Removed @ mentions
    text = re.sub(r'#', '', text) # Remove the # symbol
    text = re.sub(r'RT[\s]+', '', text) #Remove retweet
    text = re.sub(r'https?:\/\/\S+', '', text) # Remove hyperlink
    
    return text

df['Tweets'] = df['Tweets'].apply(cleanTxt)

# Show
df.head()
# Out:
#                                               Tweets
# 0  : . will develop a plan to expedite aid to Ame...
# 1  : In response to the virus, the American peopl...
# 2  : While we encourage Americans to delay electi...
# 3  : The data is clear: Our collective national e...
# 4  : This Sunday, millions of Christians will cel...

# %%
# Create a function to get the subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# Create a function to get polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# Create two new columns
df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
df['Polarity'] = df['Tweets'].apply(getPolarity)

# Show
df.head()
# Out:
#                                               Tweets  Subjectivity  Polarity
# 0  : . will develop a plan to expedite aid to Ame...      0.366667  0.216667
# 1  : In response to the virus, the American peopl...      0.500000  0.500000
# 2  : While we encourage Americans to delay electi...      0.500000  0.000000
# 3  : The data is clear: Our collective national e...      0.441667  0.362500
# 4  : This Sunday, millions of Christians will cel...      0.857143 -0.714286

# %%
# Word cloud
allWords = ' '.join(twts for twts in df['Tweets'])
wordCloud = WordCloud(width=500, height=300, random_state=21, max_font_size =199).generate(allWords)

plt.imshow(wordCloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# Create function to compute negative, neutral and positive analysis
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
df['Analysis'] = df['Polarity'].apply(getAnalysis)

# Show df
df
# Out:
#                                                Tweets  Subjectivity  Polarity  \
# 0   : In response to the virus, the American peopl...      0.500000  0.500000
# 1   : This Sunday, millions of Christians will cel...      0.857143 -0.714286
# 2   : The data is clear: Our collective national e...      0.441667  0.362500
# 3   : LIVE: Press Briefing with Coronavirus Task F...      0.500000  0.136364
# 4                                                          0.000000  0.000000
# ..                                                ...           ...       ...
# 95        Can’t see AOC plus 3 supporting Sleepy Joe!      0.250000  0.312500
# 96  Wow, Bernie is unwilling to give up his delega...      0.533333  0.308333
# 97  Bernie Sanders is OUT! Thank you to Elizabeth ...      0.297222  0.138889
# 98                           FLATTENING OF THE CURVE!      0.000000  0.000000
# 99  Once we OPEN UP OUR GREAT COUNTRY, and it will...      0.550000  0.190208
#
#     Analysis
# 0   Positive
# 1   Negative
# 2   Positive
# 3   Positive
# 4    Neutral
# ..       ...
# 95  Positive
# 96  Positive
# 97  Positive
# 98   Neutral
# 99  Positive
#
# [100 rows x 4 columns]

# %%
# Print sorted tweets
j=1
sortedDF = df.sort_values(by=['Polarity'])

for i in range(0, 100):
    if (sortedDF['Analysis'][i] == 'Positive'):
        print(str(j)+') '+ sortedDF['Tweets'][i])
        print()
        j = j+1
# Out:
# 1) : In response to the virus, the American people have launched the greatest mobilization of our society since World War II. 🇺🇸…
#
# 2) : The data is clear: Our collective national effort is saving many lives. Keep up the fight!
#
# 3) : LIVE: Press Briefing with Coronavirus Task Force
#
# 4) _regan: AG Barr says he believes Russia investigation into PresTrump was started without basis &amp; effectively amounted to an eff…
#
# 5) : Barr on the right track here. Most in the media went in the other direction.
#
# 6) The Invisible Enemy will soon be in full retreat!
#
# 7) The White House Press Conference will take place today at 1:00 P.M., recognizing that it is Good Friday!
#
# 8) HAPPY GOOD FRIDAY TO ALL!
#
# 9) Wow, Approval Rating in the Republican Party - 96%. Thank you!
#
# 10) : Very grateful for the people of Vietnam and their generosity during this time. Thank you!
#
# 11) : Coronavirus Crisis – Americans Fear the Lockdown More Than The Virus
#
# 12) : Fauci: We’re On Track For More ‘Normal’ Summer; Mnuchin: Likely To Begin ‘Reopening’ In May  http…
#
# 13) : AG William Barr on the Russia investigation: 'There's something far more troubling here'  FoxNews…
#
# 14) Democrats are blocking a 251 Billion Dollar funding boost for Small Businesses which will help them keep their employees. It should be for only that reason, with no additions. We should have a big Infrastructure Phase Four with Payroll Tax Cuts &amp; more. Big Economic Bounceback!
#
# 15) This week, in only 4 days, we had the biggest Stock Market increase since 1974. We have a great chance for the really big bounce when the Invisible Enemy is gone!
#
# 16) :  if you continue to have loud mouth low IQ Chris Hahn on your show you’re going to loose me and many other…
#
# 17) : MUST READ op-ed from : Isn’t it strange how every Democrat proposal for voting during a pandemic is exactly what Demo…
#
# 18) : "Our goal is - first, second and third - to get relief to people who need it, quickly. So, we're trying to do it as swiftly as p…
#
# 19) : The  online campaign is 🔥🔥🔥!
#
# Since going all-virtual March 13:
#
# ❗️276K NEW volunteers
# ❗️13,347,694 volunteer calls…
#
# 20) : Trump vs Establishment - Part 2!
#
# SleepyJoe Loves...
# ✅ China
# ✅ Open Borders
# ✅ Free Healthcare for Illegals
# ✅ Big Government…
#
# 21) : Team Trump Communications Director  on how important the PaycheckProtectionProgram is for American Small Busine…
#
# 22) Tim Scott is Great!
#
# 23) : Today I joined , , &amp;  on a call w Mental Health Professionals. Americans are enduring many hardships becaus…
#
# 24) : Great News: Prime Minister Boris Johnson has just been moved out of Intensive Care. Get well Boris!!!
#
# 25) : On National Former Prisoner of War Recognition Day, we honor the more than 500,000 American warriors captured while pr…
#
# 26) : Superheroes exist in real life, for we walk among them!
#
# Shout out to all the dedicated health professionals and Sailors acros…
#
# 27) : We're working with partners to get medical supplies where they are needed by:
#
# 🔹 Making the best use of supplies at hand
# 🔹 Identi…
#
# 28) _NY: Time-lapse footage shows efforts to convert sites at SUNY Old Westbury into an alternate care facility.1020 beds for various…
#
# 29) _NY: The New York District, in conjunction with state, federal and local partners, is constructing an alternate care facility for…
#
# 30) ....We will always be there for our Great Farmers, Cattlemen, Ranchers, and Producers!
#
# 31) I have directed  to expedite help to our farmers, especially to the smaller farmers who are hurting right now. I expect Secretary Purdue to use all of the funds and authorities at his disposal to make sure that our food supply is stable, strong, and safe....
#
# 32) : Project Air Bridge—a sweeping operation to keep doctors and nurses supplied with protective equipment—has completed more th…
#
# 33) : "Let me begin by expressing my sincere gratitude to the American people. Millions of Americans are making profound and diff…
#
# 34) : Our great American medical system continues to go above and beyond the call of duty. 🇺🇸
#
# 35) : LIVE: Press Briefing with Coronavirus Task Force
#
# 36) Great News: Prime Minister Boris Johnson has just been moved out of Intensive Care. Get well Boris!!!
#
# 37) On National Former Prisoner of War Recognition Day, we honor the more than 500,000 American warriors captured while protecting our way of life. We pay tribute to these Patriots for their unwavering and unrelenting spirit!
#
# 38) .  A key CoronaVirus Model is now predicting far fewer deaths than the number shown in earlier models. That’s because the American people are doing a great job. Social Distancing etc. Keep going!
#
# 39) Absentee Ballots are a great way to vote for the many senior citizens, military, and others who can’t get to the polls on Election Day. These ballots are very different from 100% Mail-In Voting, which is “RIPE for FRAUD,” and shouldn’t be allowed!
#
# 40) This morning, 450,000 protective suits landed in Dallas, Texas. This was made possible because of the partnership of two great American companies—DuPont and FedEx—and our friends in Vietnam. Thank you! _News
#
# 41) : To date, we've shipped out more than 8,000 ventilators, have an additional 10,000 ready to go, and 2,200 more will be avail…
#
# 42) : LIVE: Press Briefing with Coronavirus Task Force
#
# 43) Wishing a HAPPY PASSOVER to those celebrating in the United States, Israel, and around the world!
#
# 44) Extraordinary times require even closer cooperation between friends. Thank you India and the Indian people for the decision on HCQ. Will not be forgotten! Thank you Prime Minister  for your strong leadership in helping not just India, but humanity, in this fight!
#
# 45) Can’t see AOC plus 3 supporting Sleepy Joe!
#
# 46) Wow, Bernie is unwilling to give up his delegates, and wants more of them! What’s that all about?
#
# 47) Bernie Sanders is OUT! Thank you to Elizabeth Warren. If not for her, Bernie would have won almost every state on Super Tuesday! This ended just like the Democrats &amp; the DNC wanted, same as the Crooked Hillary fiasco. The Bernie people should come to the Republican Party, TRADE!
#
# 48) Once we OPEN UP OUR GREAT COUNTRY, and it will be sooner rather than later, the horror of the Invisible Enemy, except for those that sadly lost a family member or friend, must be quickly forgotten. Our Economy will BOOM, perhaps like never before!!!

# %%
# Plot the polarity and subjectivity
plt.figure(figsize=(8,6))
for i in range(0, df.shape[0]):
    plt.scatter(df['Polarity'][i],df['Subjectivity'][i], color='Blue')

plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Get the percentage of positive tweets
ptweets = df[df.Analysis == 'Positive']
ptweets = ptweets['Tweets']

str((ptweets.shape[0] / df.shape[0])*100)+'%'
# Out:
# '48.0%'

# %%
# Show value count

df['Analysis'].value_counts()

#plot and visualise counts
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind='bar')
plt.show()
